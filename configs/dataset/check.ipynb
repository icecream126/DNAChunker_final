# %%
from datasets import load_dataset, load_from_disk
import os
dataset_list = [
    "InstaDeepAI/nucleotide_transformer_downstream_tasks"
]
cache_path = '/workspace/huggingface/nt_disk'
for dataset in dataset_list:
    seqs = load_from_disk(os.path.join(cache_path, 'train'))
    # for each distinct task, print the sequence length. the task is the key in the dataset
    unique_tasks = list(set(dt['task']))
    for task in unique_tasks:
        print(f"Task: {task}")
        print(f"Sequence length: {max(len(seq) for seq in dt['task'==task]['sequence'])}")
        print(f"Min sequence length: {min(len(seq) for seq in dt['task'==task]['sequence'])}")
        print("\n")
    break
# Out:
# ---------------------------------------------------------------------------
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[2], line 7
#       2 dataset_list = [
#       3     "InstaDeepAI/nucleotide_transformer_downstream_tasks"
#       4 ]
#       6 for dataset in dataset_list:
# ----> 7     dt = load_dataset(dataset)['train']
#       8     # for each distinct task, print the sequence length. the task is the key in the dataset
#       9     unique_tasks = list(set(dt['task']))
#
# File /venv/tokenize/lib/python3.8/site-packages/datasets/load.py:2128, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2123 verification_mode = VerificationMode(
# ...

# %%
from datasets import load_dataset, load_from_disk
dataset_list = [
    "katarinagresova/Genomic_Benchmarks_human_ensembl_regulatory",
    "katarinagresova/Genomic_Benchmarks_demo_human_or_worm",
    "katarinagresova/Genomic_Benchmarks_human_ocr_ensembl",
    "katarinagresova/Genomic_Benchmarks_drosophila_enhancers_stark",
    "katarinagresova/Genomic_Benchmarks_dummy_mouse_enhancers_ensembl",
    "katarinagresova/Genomic_Benchmarks_demo_coding_vs_intergenomic_seqs",
    "katarinagresova/Genomic_Benchmarks_human_enhancers_ensembl",
    "katarinagresova/Genomic_Benchmarks_human_enhancers_cohn",
    "katarinagresova/Genomic_Benchmarks_human_nontata_promoters",
]

for dataset in dataset_list:
    dt = load_dataset(dataset)['train']
    print(f"{dataset.replace('katarinagresova/', '')}")
    print(f"train len: {len(dt)}")
    print(f"classes: {len(unique(dt['label']))}")
    print(f"max_length: {max(len(seq) for seq in dt['sequence'])}")
    break
# Out:
# Genomic_Benchmarks_human_ensembl_regulatory
# train len: 231348
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      16 print(f"{dataset.replace('katarinagresova/', '')}")
#      17 print(f"train len: {len(dt)}")
# ---> 18 print(f"classes: {len(unique(dt['label']))}")
#      19 print(f"max_length: {max(len(seq) for seq in dt['sequence'])}")
#      20 break
#
# NameError: name 'unique' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
